# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/codebasics/py/master/pandas/1_intro/nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# **^this is before data munging.......
# cleaning messy data called as data munging or data wrangling........
# after data munging>**

# %%
df.fillna(0,inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %% [markdown]
# **Dataframe is main object in pandas. it is used to represent data with rows and coloumns (tabular or ecxel spreadsheet like data)**

# %% [markdown]
# **1) creating dataframe, 2) Dealing with rows and coloumns 3) Operation: min,max,std,describe 4) conditional selection 5) set_index**

# %%
import pandas as pd
df = pd.read_csv("wed.csv")
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   rain
# 1  01-02-2017           35          7  sunny
# 2  01-03-2017           28          2   snow
# 3  01-04-2017           24          7   snow
# 4  01-05-2017           32          4   rain
# 5  01-06-2017           32          2  sunny

# %% [markdown]
# **creating the dataframe using code>>>>>>>**

# %%
weather_data = {
    'day' : ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temprature' : [32,35,28,24,32,32],
    'windspeed': [6,7,2,7,4,2],
    'event' : ['rain','sunny','snow','snow','rain','sunny']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temprature  windspeed  event
# 0  1/1/2017          32          6   rain
# 1  1/2/2017          35          7  sunny
# 2  1/3/2017          28          2   snow
# 3  1/4/2017          24          7   snow
# 4  1/5/2017          32          4   rain
# 5  1/6/2017          32          2  sunny

# %%
rows,columns = df.shape

# %%
columns
# Out:
# 4

# %%
df.head()
# Out:
#         day  temprature  windspeed  event
# 0  1/1/2017          32          6   rain
# 1  1/2/2017          35          7  sunny
# 2  1/3/2017          28          2   snow
# 3  1/4/2017          24          7   snow
# 4  1/5/2017          32          4   rain

# %%
df.head(2) #for showing some amount of rows
# Out:
#         day  temprature  windspeed  event
# 0  1/1/2017          32          6   rain
# 1  1/2/2017          35          7  sunny

# %%
df.tail() #this will print last 5 rows
# Out:
#         day  temprature  windspeed  event
# 1  1/2/2017          35          7  sunny
# 2  1/3/2017          28          2   snow
# 3  1/4/2017          24          7   snow
# 4  1/5/2017          32          4   rain
# 5  1/6/2017          32          2  sunny

# %%
df.tail(1)
# Out:
#         day  temprature  windspeed  event
# 5  1/6/2017          32          2  sunny

# %%
df[2:5]
# Out:
#         day  temprature  windspeed event
# 2  1/3/2017          28          2  snow
# 3  1/4/2017          24          7  snow
# 4  1/5/2017          32          4  rain

# %%
df.columns
# Out:
# Index(['day', 'temprature', 'windspeed', 'event'], dtype='object')

# %%
df.day # to print individual containt of column
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df['event']) #will show the type of dataframe in this case it is series
# Out:
# pandas.core.series.Series

# %%
df[['event','day','temprature']]
# Out:
#    event       day  temprature
# 0   rain  1/1/2017          32
# 1  sunny  1/2/2017          35
# 2   snow  1/3/2017          28
# 3   snow  1/4/2017          24
# 4   rain  1/5/2017          32
# 5  sunny  1/6/2017          32

# %% [markdown]
# # operations with dataset

# %%
df['temprature'].max() #to get max out of given dataset
# Out:
# 35

# %%
df['temprature'].min()
# Out:
# 24

# %%
df['temprature'].mean()
# Out:
# 30.5

# %%
df['temprature'].std()
# Out:
# 3.8858718455450894

# %%
df.describe()
# Out:
#        temprature  windspeed
# count    6.000000   6.000000
# mean    30.500000   4.666667
# std      3.885872   2.338090
# min     24.000000   2.000000
# 25%     29.000000   2.500000
# 50%     32.000000   5.000000
# 75%     32.000000   6.750000
# max     35.000000   7.000000

# %%
df[df.temprature>=32]
# Out:
#         day  temprature  windspeed  event
# 0  1/1/2017          32          6   rain
# 1  1/2/2017          35          7  sunny
# 4  1/5/2017          32          4   rain
# 5  1/6/2017          32          2  sunny

# %%
df[df.temprature == df.temprature.max()]
# Out:
#         day  temprature  windspeed  event
# 1  1/2/2017          35          7  sunny

# %%
df[['day','temprature']][df.temprature == df.temprature.max()]
# Out:
#         day  temprature
# 1  1/2/2017          35

# %%
df
# Out:
#         day  temprature  windspeed  event
# 0  1/1/2017          32          6   rain
# 1  1/2/2017          35          7  sunny
# 2  1/3/2017          28          2   snow
# 3  1/4/2017          24          7   snow
# 4  1/5/2017          32          4   rain
# 5  1/6/2017          32          2  sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#           temprature  windspeed  event
# day
# 1/1/2017          32          6   rain
# 1/2/2017          35          7  sunny
# 1/3/2017          28          2   snow
# 1/4/2017          24          7   snow
# 1/5/2017          32          4   rain
# 1/6/2017          32          2  sunny

# %%
df.loc['1/3/2017']
# Out:
# temprature      28
# windspeed        2
# event         snow
# Name: 1/3/2017, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temprature  windspeed  event
# 0  1/1/2017          32          6   rain
# 1  1/2/2017          35          7  sunny
# 2  1/3/2017          28          2   snow
# 3  1/4/2017          24          7   snow
# 4  1/5/2017          32          4   rain
# 5  1/6/2017          32          2  sunny

# %%
df.set_index('event',inplace=True)
df
# Out:
#             day  temprature  windspeed
# event
# rain   1/1/2017          32          6
# sunny  1/2/2017          35          7
# snow   1/3/2017          28          2
# snow   1/4/2017          24          7
# rain   1/5/2017          32          4
# sunny  1/6/2017          32          2

# %%
df.loc['snow']
# Out:
#             day  temprature  windspeed
# event
# snow   1/3/2017          28          2
# snow   1/4/2017          24          7

# %% [markdown]
# # ***Methods of creating data frame***

# %%
pd.read_csv("vid3.csv")
# Out:
#           day  temprature  windspeed  event
# 0  01-01-2017          32          6   rain
# 1  01-02-2017          35          7  sunny
# 2  01-03-2017          28          2   snow

# %% [markdown]
# df = pd.read_exel ### we can use xlsx file as inpute

# %%
weather_data = {
    'day' : ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temprature' : [32,35,28,24,32,32],
    'windspeed': [6,7,2,7,4,2],
    'event' : ['rain','sunny','snow','snow','rain','sunny']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temprature  windspeed  event
# 0  1/1/2017          32          6   rain
# 1  1/2/2017          35          7  sunny
# 2  1/3/2017          28          2   snow
# 3  1/4/2017          24          7   snow
# 4  1/5/2017          32          4   rain
# 5  1/6/2017          32          2  sunny

# %%
#dataframe making using tupple
weather_data = [
    ('1/1/201',32,6,'Rain'),
    ('1/2/201',35,7,'sunny'),
    ('1/3/201',28,2,'snow'),
]
df = pd.DataFrame(weather_data,columns=['day','temprature','windspeed','event'])
df
# Out:
#        day  temprature  windspeed  event
# 0  1/1/201          32          6   Rain
# 1  1/2/201          35          7  sunny
# 2  1/3/201          28          2   snow

# %%
#dictionary approch
weather_data = [
    {'day':'1/1/2017','temp':32,'windspped':6,'event':'rain'},
    {'day':'1/2/2017','temp':35,'windspped':7,'event':'sunny'},
    {'day':'1/3/2017','temp':28,'windspped':2,'event':'snow'},
]
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temp  windspped  event
# 0  1/1/2017    32          6   rain
# 1  1/2/2017    35          7  sunny
# 2  1/3/2017    28          2   snow

# %% [markdown]
# vid 4

# %%
df = pd.read_csv("vid4.csv",skiprows=1)
df
# Out:
#   googl           27.82   87   854     larry page
# 0   wmt            4.61  484    65            n.a
# 1  msft              -1   85    64     bill gates
# 2   ril  not available    50  1023  mukesh ambani
# 3  tata             5.6   -1   n.a     ratan tata

# %%
df = pd.read_csv("vid4.csv",header=1)
df
# Out:
#   googl           27.82   87   854     larry page
# 0   wmt            4.61  484    65            n.a
# 1  msft              -1   85    64     bill gates
# 2   ril  not available    50  1023  mukesh ambani
# 3  tata             5.6   -1   n.a     ratan tata

# %%
df = pd.read_csv("vid4.csv",header=None, names=["ticker","eps","revenue","price","people"])
df
# missing header
# this method is use when there is no column names given is csv file but u want it in panadas dataframe
# Out:
#     ticker             eps  revenue  price         people
# 0  tickers             eps  revenue  price         people
# 1    googl           27.82       87    854     larry page
# 2      wmt            4.61      484     65            n.a
# 3     msft              -1       85     64     bill gates
# 4      ril  not available        50   1023  mukesh ambani
# 5     tata             5.6       -1    n.a     ratan tata

# %%
df = pd.read_csv("vid4.csv")
df
# Out:
#   tickers             eps  revenue price         people
# 0   googl           27.82       87   854     larry page
# 1     wmt            4.61      484    65            n.a
# 2    msft              -1       85    64     bill gates
# 3     ril  not available        50  1023  mukesh ambani
# 4    tata             5.6       -1   n.a     ratan tata

# %%
df = pd.read_csv("vid4.csv", nrows=3)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   googl  27.82       87    854  larry page
# 1     wmt   4.61      484     65         n.a
# 2    msft  -1.00       85     64  bill gates

# %%
df = pd.read_csv("vid4.csv", na_values=["not available","n.a"])
df
#use for replacing n.a values with NAN
# Out:
#   tickers             eps  revenue   price         people
# 0   googl           27.82       87   854.0     larry page
# 1     wmt            4.61      484    65.0            NaN
# 2    msft              -1       85    64.0     bill gates
# 3     ril  not available        50  1023.0  mukesh ambani
# 4    tata             5.6       -1     NaN     ratan tata

# %%
df = pd.read_csv("vid4.csv", na_values={
    'eps':["not available","n.a"],
    'revenue':["not available","n.a",-1],
     'price':["not available","n.a"],
     'people':["not available","n.a",-1],
    
    
})
df
#important for data monging or data wrangling
# Out:
#   tickers             eps  revenue   price         people
# 0   googl           27.82     87.0   854.0     larry page
# 1     wmt            4.61    484.0    65.0            NaN
# 2    msft              -1     85.0    64.0     bill gates
# 3     ril  not available      50.0  1023.0  mukesh ambani
# 4    tata             5.6      NaN     NaN     ratan tata

# %% [markdown]
# # ***writing back to csv ↓***

# %%
df.to_csv('new.csv',index=False) #if want to hide someinfo ex: header=false,index=flase

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("new.csv",columns=['tickers','eps'])

# %%
df=pd.read_excel("vid4exel.xlsx","Sheet1")
df
# Out:
#   tickers    eps  revenue price         people
# 0   googl  27.82       87   854     larry page
# 1     wmt   4.61      484    65            n.a
# 2    msft     -1       85    64     bill gates
# 3     ril    n.a       50  1023  mukesh ambani
# 4    tata    5.6       -1   n.a     ratan tata

# %%
def convert_people_cell(cell):
    if cell=="n.a":
        return 'sam walton'
    return cell

df=pd.read_excel("vid4exel.xlsx","Sheet1", converters = {
    'people': convert_people_cell
    })

df
# Out:
#   tickers    eps  revenue price         people
# 0   googl  27.82       87   854     larry page
# 1     wmt   4.61      484    65     sam walton
# 2    msft     -1       85    64     bill gates
# 3     ril    n.a       50  1023  mukesh ambani
# 4    tata    5.6       -1   n.a     ratan tata

# %%
df.to_excel("vid4new.xlsx",sheet_name="stocks")

# %% [markdown]
# vid4 at 21.00
