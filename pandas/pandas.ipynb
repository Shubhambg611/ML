# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":['shubham','chirag','siddhi','abhishek'],
    "marks":[92,34,25,17],
    "city":['mumbai','pune','ratnagiri','dhule']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#        name  marks       city
# 0   shubham     92     mumbai
# 1    chirag     34       pune
# 2    siddhi     25  ratnagiri
# 3  abhishek     17      dhule

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv',index=False) #it will delete the index coloumn

# %%
df.head(2)
# Out:
#       name  marks    city
# 0  shubham     92  mumbai
# 1   chirag     34    pune

# %%
df.tail(2)
# Out:
#        name  marks       city
# 2    siddhi     25  ratnagiri
# 3  abhishek     17      dhule

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   42.000000
# std    34.048984
# min    17.000000
# 25%    23.000000
# 50%    29.500000
# 75%    48.500000
# max    92.000000

# %%
sp = pd.read_csv('sp1.csv')

# %%
sp
# Out:
#      Unnamed: 0       Date Injury Location  Gender Age Group   Incident Type  \
# 0             0   1-Jan-20        Multiple    Male     25-34            Burn
# 1             1   3-Jan-20             NaN    Male     35-49         Vehicle
# 2             2   3-Jan-20             Eye    Male     18-24             Cut
# 3             3   4-Jan-20            Legs  Female       50+  Falling object
# 4             4   7-Jan-20            Legs    Male     25-34         Lifting
# ..          ...        ...             ...     ...       ...             ...
# 509         509  26-Jun-22            Head  Female     25-34   Crush & Pinch
# 510         510  27-Jun-22           Hands    Male     25-34         Lifting
# 511         511  28-Jun-22           Hands    Male     25-34             Cut
# 512         512  28-Jun-22           Trunk    Male       50+  Falling object
# 513         513  28-Jun-22           Hands    Male     18-24         Vehicle
#
# ...

# %%
sp['Plant'][50] = 50
# Out:
# C:\Users\Shubham\AppData\Local\Temp/ipykernel_25308/2078566254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp['Plant'][50] = 50

# %%
sp['Plant'][50]
# Out:
# 50

# %%
sp.to_csv('sp1.csv') #changes updated in exel file
